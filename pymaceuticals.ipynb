# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Ramicane and Capomulin had much lower final tumor volumes than Infubanol and Ceftamin as seen in the box plot distribution. For Capomulin (our researched regimen), a sharp decrease can be expected around time point 25 and 35, as shown in mouse l509. We got to observe that mouse weight has a positive correlation with tumor weight, which makes sense since a bigger body would be able to have a bigger tumor attached to it. Given that we had plenty of research data as seen in our bar plot that shows unique measurements for the regimens, I'd say that it's safe to conclude that Capomulin does indeed shrink tumors in mice over time compared to most other regimens.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_data = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="inner")

# Display the data table for preview
mouse_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice (should be 249 unique ids)
mouse_data["Mouse ID"].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mice = mouse_data[mouse_data.duplicated(subset=["Mouse ID", "Timepoint"])]
duplicate_mice["Mouse ID"]
# Out:
# 909    g989
# 911    g989
# 913    g989
# 915    g989
# 917    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_data = mouse_data.drop(mouse_data[mouse_data["Mouse ID"] == "g989"].index)

# %%
# Checking the number of mice in the clean DataFrame (should be 248).
mouse_data["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.

mean_tumor_volume = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median_tumor_volume = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
tumor_volume_variance = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
tumor_volume_std_dev = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
tumor_volume_sem = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

summary_stats = pd.DataFrame({
    "Mean Tumor Volume": mean_tumor_volume,
    "Median Tumor Volume": median_tumor_volume,
    "Tumor Volume Variance": tumor_volume_variance,
    "Tumor Volume Std. Dev.": tumor_volume_std_dev,
    "Tumor Volume Std. Err.": tumor_volume_sem
})

summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line

summary_stats_agg = mouse_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(
    Mean_Tumor_Volume="mean",
    Median_Tumor_Volume="median",
    Tumor_Volume_Variance="var",
    Tumor_Volume_Std_Dev="std",
    Tumor_Volume_Std_Err="sem"
)

summary_stats_agg
# Out:
#               Mean_Tumor_Volume  Median_Tumor_Volume  Tumor_Volume_Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor_Volume_Std_Dev  Tumor_Volume_Std_Err
# Drug Regimen
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
# Our instructor has given explicit permission to use seaborn for prettier visualization. Thanks prof!

drug_counts = mouse_data["Drug Regimen"].value_counts().reset_index()
drug_counts.columns = ["Drug Regimen", "Count"]
plt.figure(figsize=(10, 6))
sns.barplot(x="Drug Regimen", y="Count", data=drug_counts)
plt.xlabel("Drug Regimen")
plt.xticks(rotation=45) # I think this looks prettier than a 90 degree rotation
plt.ylabel("Number of Unique Mouse ID/Timepoints")
plt.title("Unique Mouse Measurements for Each Drug Regimen")
plt.show()

# %%
# Once again note that our instructor gave us explicit permission to use seaborn

# %%
# Generate a pie chart showing the distribution of unique female versus male mice used in the study
# Seaborn doesn't have pie charts, so I'll be using matplotlib and a seaborn color palette 

# Get the unique mice with their gender
sex_counts = mouse_data["Sex"].value_counts().reset_index()
sex_counts.columns = ["Sex", "Count"]

# Make the pie chart
plt.figure(figsize=(5, 5))
palette_color = sns.color_palette('deep') 
plt.pie(sex_counts["Count"], labels=sex_counts["Sex"], autopct='%1.1f%%', colors=palette_color)
plt.title("Distribution of Mouse Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoints = mouse_data.groupby("Mouse ID")["Timepoint"].max().reset_index()
last_timepoints.columns = ["Mouse ID", "Last Timepoint"]

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volumes = pd.merge(last_timepoints, mouse_data, how="left", left_on=["Mouse ID", "Last Timepoint"], right_on=["Mouse ID", "Timepoint"])
final_tumor_volumes.head()
# Out:
#   Mouse ID  Last Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203              45    Infubinol  Female          20          23
# 1     a251              45    Infubinol  Female          21          25
# 2     a262              45      Placebo  Female          17          29
# 3     a275              45     Ceftamin  Female          20          28
# 4     a366              30     Stelasyn  Female          16          29
#
#    Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0         45           67.973419                 2
# 1         45           65.525743                 1
# 2         45           70.717621                 4
# 3         45           62.999356                 3
# 4         30           63.440686                 1

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
for treatment in treatments:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    treatment_data = final_tumor_volumes.loc[final_tumor_volumes["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]

    # add subset
    tumor_vol_data.append(treatment_data)

    # Determine outliers using upper and lower bounds
    quartiles = treatment_data.quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    outliers = treatment_data[(treatment_data < lower_bound) | (treatment_data > upper_bound)]
    print(f"{treatment}'s potential outliers: {outliers.tolist()}")
# Out:
# Capomulin's potential outliers: []
# Ramicane's potential outliers: []
# Infubinol's potential outliers: [36.3213458]
# Ceftamin's potential outliers: []

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
plt.figure(figsize=(8, 6))
sns.boxplot(x="Drug Regimen", y="Tumor Volume (mm3)", data=final_tumor_volumes[final_tumor_volumes["Drug Regimen"].isin(treatments)],
            flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 10, "linestyle": "none"})
plt.xlabel("Drug Regimen")
plt.ylabel("Final Tumor Volume (mm3)")
plt.title("Distribution of Final Tumor Volume by Drug Regimen")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

single_mouse_data = mouse_data[(mouse_data["Drug Regimen"] == "Capomulin") & (mouse_data["Mouse ID"] == "l509")]
plt.figure(figsize=(8, 6))
sns.lineplot(data=single_mouse_data, x="Timepoint", y="Tumor Volume (mm3)", marker="o")
plt.xlabel("Timepoint") # I have no idea what the units for this is, I don't think it's specified anywhere
plt.ylabel("Tumor Volume (mm3)")
plt.title(f"Capomulin Treatment of My Favorite Mouse, l509")
plt.grid(True)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

capomulin_data = mouse_data[mouse_data["Drug Regimen"] == "Capomulin"]
avg_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean().reset_index()
avg_tumor_volume.columns = ["Mouse ID", "Average Tumor Volume"]
capomulin_summary = pd.merge(avg_tumor_volume, capomulin_data[["Mouse ID", "Weight (g)"]].drop_duplicates(), on="Mouse ID")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=capomulin_summary, x="Weight (g)", y="Average Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Mouse Weight vs. Average Tumor Volume on Capomulin")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
x = capomulin_summary["Weight (g)"]
y = capomulin_summary["Average Tumor Volume"]
slope, intercept = np.polyfit(x, y, 1)
line = slope * x + intercept
correlation = np.corrcoef(x, y)[0, 1]
print(f"The correlation between mouse weight and average tumor volume is {correlation:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=capomulin_summary, x="Weight (g)", y="Average Tumor Volume")
plt.plot(x, line, color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Mouse Weight vs Average Tumor Volume on Capomulin")
plt.show()
# Out:
# The correlation between mouse weight and average tumor volume is 0.84
